# %%
# https://docs.python-guide.org/scenarios/xml/
# using xmltodict: https://github.com/martinblech/xmltodict

# I should be able to use streaming mode to extract just what I want... 
# but I need to explore how everything is broken down first.

# %%
# Oh forget this.
# I only need a rather small subset.
# I'll use the wikipedia python package and pull data as needed for specific pages.
# https://wikipedia.readthedocs.io/en/latest/

# %%
import xmltodict

# %%
# Use a test file of the first ~10k lines in the wiki dump, plus closing 
# wiki_fp = '/Volumes/seagate_external_drive/ten_k_lines_wiki.xml'
wiki_fp = '/Volumes/ja2/vegan/vegan_parser/data_source/ten_k_lines_wiki.xml'

# %%
with open(wiki_fp) as fd:
    doc = xmltodict.parse(fd.read())

# %%
doc['mediawiki'].keys()
# Out:
# odict_keys(['@xmlns', '@xmlns:xsi', '@xsi:schemaLocation', '@version', '@xml:lang', 'siteinfo', 'page'])

# %%
len(doc['mediawiki']['page'])
# Out:
# 75

# %%
# len(doc['mediawiki']['page']) is 75 --> 75 pages in this subset

# %%
doc['mediawiki']['page'][0]
# Out:
# OrderedDict([('title', 'AccessibleComputing'),
#              ('ns', '0'),
#              ('id', '10'),
#              ('redirect', OrderedDict([('@title', 'Computer accessibility')])),
#              ('revision',
#               OrderedDict([('id', '854851586'),
#                            ('parentid', '834079434'),
#                            ('timestamp', '2018-08-14T06:47:24Z'),
#                            ('contributor',
#                             OrderedDict([('username', 'Godsy'),
#                                          ('id', '23257138')])),
#                            ('comment',
#                             'remove from category for seeking instructions on rcats'),
#                            ('model', 'wikitext'),
#                            ('format', 'text/x-wiki'),
#                            ('text',
#                             OrderedDict([('@xml:space', 'preserve'),
#                                          ('#text',
# ...

# %%
# The pages are:
for entry in doc['mediawiki']['page'][0:10]:
    print(entry['title'])
    
#
# Out:
# AccessibleComputing
# Anarchism
# AfghanistanHistory
# AfghanistanGeography
# AfghanistanPeople
# AfghanistanCommunications
# AfghanistanTransportations
# AfghanistanMilitary
# AfghanistanTransnationalIssues
# AssistiveTechnology

# %%
# example of page that's not redirect...

doc['mediawiki']['page'][11]
# Out:
# OrderedDict([('title', 'Autism'),
#              ('ns', '0'),
#              ('id', '25'),
#              ('revision',
#               OrderedDict([('id', '930524291'),
#                            ('parentid', '930523037'),
#                            ('timestamp', '2019-12-13T02:28:01Z'),
#                            ('contributor',
#                             OrderedDict([('username', 'AnomieBOT'),
#                                          ('id', '7611264')])),
#                            ('comment', 'Fixing reference errors'),
#                            ('model', 'wikitext'),
#                            ('format', 'text/x-wiki'),
#                            ('text',
#                             OrderedDict([('@xml:space', 'preserve'),
#                                          ('#text',
# ...

# %%
doc['mediawiki']['page'][11].keys()
# Out:
# odict_keys(['title', 'ns', 'id', 'revision'])

# %%
# example: doc['mediawiki']['page'][11]['title']
# Out:
# 'Autism'

# %%
with open(wiki_fp) as fd:
    doc2 = xmltodict.parse(fd.read(), item_callback=process_func)

# %%
doc2
# Out:
# OrderedDict([('mediawiki',
#               OrderedDict([('@xmlns',
#                             'http://www.mediawiki.org/xml/export-0.10/'),
#                            ('@xmlns:xsi',
#                             'http://www.w3.org/2001/XMLSchema-instance'),
#                            ('@xsi:schemaLocation',
#                             'http://www.mediawiki.org/xml/export-0.10/ http://www.mediawiki.org/xml/export-0.10.xsd'),
#                            ('@version', '0.10'),
#                            ('@xml:lang', 'en'),
#                            ('siteinfo',
#                             OrderedDict([('sitename', 'Wikipedia'),
#                                          ('dbname', 'enwiki'),
#                                          ('base',
#                                           'https://en.wikipedia.org/wiki/Main_Page'),
#                                          ('generator',
#                                           'MediaWiki 1.35.0-wmf.11'),
# ...
