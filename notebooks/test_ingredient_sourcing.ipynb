# %%
import pandas as pd

# %%
ingredient_data_fp = '/Volumes/ja2/vegan/vegan_parser/data_source/dataframe_with_syns5.csv'

# %%
df = pd.read_csv(ingredient_data_fp)

# %%
df.head()
# Out:
#               datetime_pulled  search_page_num    chemical_name  \
# 0  2019-12-07 11:47:29.665736                1            water
# 1  2019-12-07 11:47:29.665736                1             aqua
# 2  2019-12-07 11:47:29.665736                1  deionized water
# 3  2019-12-07 11:47:29.665736                1  distilled water
# 4  2019-12-07 11:47:29.665736                1        onsen-sui
#
#                                            score_url data_availability  \
# 0  https://www.ewg.org/skindeep/squircle/show.svg...            Robust
# 1  https://www.ewg.org/skindeep/squircle/show.svg...            Robust
# 2  https://www.ewg.org/skindeep/squircle/show.svg...            Robust
# 3  https://www.ewg.org/skindeep/squircle/show.svg...            Robust
# 4  https://www.ewg.org/skindeep/squircle/show.svg...            Robust
#
#   chemical_concerns chemical_functions chemical_about  \
# 0               NaN            solvent            NaN
# ...

# %%
df[df.is_syn==False].sort_values(by='datetime_pulled')[11:15]
# Out:
#                 datetime_pulled  search_page_num  chemical_name  \
# 305  2019-12-07 11:49:58.508512                1    citric acid
# 315  2019-12-07 11:50:12.079460                1  methylparaben
# 348  2019-12-07 11:50:25.709281                1  propylparaben
# 367  2019-12-07 11:50:39.217442                1  disodium edta
#
#                                                               score_url  \
# 305  https://www.ewg.org/skindeep/squircle/show.svg?score=2&score_min=1
# 315  https://www.ewg.org/skindeep/squircle/show.svg?score=4&score_min=4
# 348  https://www.ewg.org/skindeep/squircle/show.svg?score=7&score_min=5
# 367  https://www.ewg.org/skindeep/squircle/show.svg?score=1&score_min=1
#
#     data_availability  \
# 305              Good
# 315              Fair
# 348              Fair
# 367              Fair
#
#                                                                                        chemical_concerns  \
# ...

# %%
# categories: animal, plant, petroleum, mineral.
# let's just collect the categories of the first most popular ingredients, listed by order in the ingredients list

# %%
pd.set_option('display.max_colwidth', 100)
